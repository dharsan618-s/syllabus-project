# %% [markdown]
# # `str` Object Exercises

# %% [markdown]
# ## Part A - Directly calling the method on a string literal
#
# Use methods directly on string objects without variables

# %% [markdown]
# 1. **Capitalize** the first character of the string `"hello world"`

# %%
"hello world".capitalize()
# Out:
# 'Hello world'

# %% [markdown]
# 2. Display whether `"Python programming"` **starts with** `"Py"`.

# %%
'python gaming'.startswith('py')
# Out:
# True

# %% [markdown]
# 3. **Count** how many times the letter `'a'` appears in the string `'banana'`.

# %%
'banana'.count('a')
# Out:
# 3

# %% [markdown]
# 4. **Find** the position of the letter `'o'` in `'chocolate'`

# %%
'chocolate'.find('o')
# Out:
# 2

# %% [markdown]
# 5. **Strip** the spaces in the start and end of the string `' spaced out '`.

# %%
'  spaced out   '.strip()
# Out:
# 'spaced out'

# %% [markdown]
# 6. Show the **uppercase** form of `'greetings'`

# %%
'greetings'.upper()
# Out:
# 'GREETINGS'

# %% [markdown]
# 7. Show the **lowercase** form of `'DATA'`

# %%
'DATA'.lower()
# Out:
# 'data'

# %% [markdown]
# 8. Check whether the string `'chatbot'` **ends with** `'bot'`

# %%
'chatbot'.endswith('bot')
# Out:
# True

# %% [markdown]
# ## Part B - Assign a string to a variable, then call a method on it.

# %% [markdown]
# 9. Assign the string `'python is fun'` to a variable named `text`, then display it in **title case**.

# %%
text ='python is fun'
text.title()
# Out:
# 'Python Is Fun'

# %% [markdown]
# 10. Create a variable `name` with the value `'Guido Van Rossum'` and show it with the first letter **capitalized**.

# %%
name ='guido van rossum'
name.capitalize()
# Out:
# 'Guido van rossum'

# %% [markdown]
# 11. Store the string `'mississippi'` in a variable `river`, then **count** how many times the letter `'s'` appears.

# %%
river ='mississipi'
river.count('s')
# Out:
# 4

# %% [markdown]
# 12. Create a variable `quote` holding `'to be or not to be'` and **find** the index position of the substring `'not'`.

# %%
quote='to be or not to be'
quote.find('not')
# Out:
# 9

# %% [markdown]
# 13. Make a variable `phrase` with the value `'learning python'` and check if it **starts with** `'learn'`.

# %%
phrase='learning python'
phrase.startswith('learn')
# Out:
# True

# %% [markdown]
# 14. Set `message` to `'programming is cool'` and check if it **ends with** `'cool'`.

# %%
message='programming is cool'
message.endswith('cool')
# Out:
# True

# %% [markdown]
# ## Part C - Call/Invoke the method and reassign or store the result

# %% [markdown]
# 15. Assign `'good morning'` to `greeting`, then **capitalize** it and reassign the result back to `greeting`.

# %%
greeting ='good morning'
greeting=greeting.capitalize()

# %% [markdown]
# 16. Set `title` to `'the lord of the rings'` and convert it to **title case**, storing the result in a new variable named `formatted_title`

# %%
title ='the lord of the rings'
formtedtitle=title.title()

# %% [markdown]
# 17. Store `'PYTHON ROCKS'` in `sentence`, then convert it to **lowercase** and save the result in a different variable `lower_sentence`

# %%
sentence='python rocks'
lower sentence=sentence.lower()
# Out:
# 'python rocks'

# %% [markdown]
# 18. Store `' CONTACT@DATAMITES.COM '` in `email`, first **strip** the spaces and then convert it to **lowercase**, updating the variable after each step. At each step, assign the result to the same variable `email`.

# %%
email='   CONTACT@DATAMITES.COM  '
email=email.lower()
email=email.strip()
